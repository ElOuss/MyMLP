# %% [markdown]
# # Cas de Tests

# %%
import numpy as np
from MyMLP.MyMLP import MyMLP
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ## Classification

# %% [markdown]
# ### Linear Simple : mlp(2,1)

# %%
my_mlp = MyMLP([2, 1])

# %%
X = np.array([
      [1, 1],
      [2, 3],
      [3, 3]
])
Y = np.array([
      [1],
      [-1],
      [-1]
])

# %%
# Entraîner le modèle
epochs = 100000
rate = 0.1
loss_history = []

my_mlp.train(X, Y, is_classification=True, iteration_count=epochs, alpha=rate)
# Prédire les sorties pour les entrées fournies
predictions = [my_mlp.predict(x, is_classification=True) for x in X]
     
loss = my_mlp.calculate_loss(X,Y)
loss_history.append(loss)
      
accuracy = my_mlp.calculate_accuracy(X,Y)
      #accuracies.append(accuracy)
print(accuracy)
print(predictions)
#afficher la fonction loss
plt.plot(loss_history)
plt.xlabel("Epoch")
plt.ylabel("Valeur de la fonction de perte")
plt.title("Évolution de la fonction de perte")
plt.show()
# Out:
# 1.0
# [[0.991831668841763], [-0.995837769143647], [-0.9966706460870675]]

# %%
#Conversion des prédictions en couleurs pour le tracé du graphe
x_min, x_max = 0., 3.
y_min, y_max = 0., 3.
step = 0.01
xx, yy = np.meshgrid(np.arange(x_min, x_max, step), np.arange(y_min, y_max, step))
gridpoints = np.c_[xx.ravel(), yy.ravel()]


output_ptr =  [my_mlp.predict(x, is_classification=True) for x in gridpoints]
# predicted_outputs.append(predicted_output)
print(output_ptr)

plt.scatter(X[:, 0], X[:, 1], c=np.argmax(Y, axis=1))
output_ptr = np.array(output_ptr)
contour = output_ptr[:, 0].reshape(xx.shape)

plt.contourf(xx, yy, contour, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.5)

#plt.title(title)
# Out:
# [[0.9999785526737291], [0.9999785046449909], [0.9999784565086993], [0.9999784082646133], [0.9999783599124915], [0.999978311452092], [0.9999782628831726], [0.9999782142054899], [0.9999781654188006], [0.9999781165228605], [0.9999780675174249], [0.9999780184022488], [0.9999779691770863], [0.9999779198416912], [0.9999778703958164], [0.9999778208392149], [0.9999777711716386], [0.9999777213928387], [0.9999776715025666], [0.9999776215005723], [0.9999775713866059], [0.9999775211604165], [0.9999774708217528], [0.9999774203703631], [0.9999773698059947], [0.9999773191283948], [0.9999772683373099], [0.9999772174324857], [0.9999771664136675], [0.9999771152806002], [0.9999770640330279], [0.999977012670694], [0.9999769611933418], [0.9999769096007135], [0.9999768578925512], [0.999976806068596], [0.9999767541285886], [0.9999767020722692], [0.9999766498993774], [0.999976597609652], [0.9999765452028315], [0.9999764926786536], [0.9999764400368556], [0.9999763872771741], [0.9999763343993451], [0.9999762814031039], [0.9999762282881856], [0.9999761750543241], [0.9999761217012534], [0.9999760682287064], [0.9999760146364156], [0